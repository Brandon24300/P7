# %% [markdown]
# # P7 :  Implémentez un modèle de scoring #
#
# Auteur: Brandon Zermelwall
#
# Notebook support : https://www.kaggle.com/willkoehrsen/start-here-a-gentle-introduction#Conclusions
#
# Algorithme :
# P7 -
#
# Partie Dashboard:
#
# Choisir un client afficher s'il est solvable ou insolvable
# Afficher des graphiques permettant de comprendre pourquoi il est solvable ou insolvable
# hirokou
#
# Livrable de 10 pages :
# Décrire ce que j'ai fait et justifier mes choix

# %%
import pandas as pd

# %%
df_application_test = pd.read_csv('data/application_test.csv')
df_application_train = pd.read_csv('data/application_train.csv')
df_bureau = pd.read_csv('data/bureau.csv')
df_bureau_balance = pd.read_csv('data/bureau_balance.csv')
df_credit_card_balance = pd.read_csv('data/credit_card_balance.csv')
# df_home_credit = pd.read_csv('data/HomeCredit_columns_description.csv')
df_installments_payments = pd.read_csv('data/installments_payments.csv')
df_pov_cash_balance = pd.read_csv('data/POS_CASH_balance.csv')
df_previous_application = pd.read_csv('data/previous_application.csv')
df_sample_submission = pd.read_csv('data/sample_submission.csv')

# %%
df_bureau
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0            215354       5714462        Closed      currency 1         -497
# 1            215354       5714463        Active      currency 1         -208
# 2            215354       5714464        Active      currency 1         -203
# 3            215354       5714465        Active      currency 1         -203
# 4            215354       5714466        Active      currency 1         -629
# ...             ...           ...           ...             ...          ...
# 1716423      259355       5057750        Active      currency 1          -44
# 1716424      100044       5057754        Closed      currency 1        -2648
# 1716425      100044       5057762        Closed      currency 1        -1809
# 1716426      246829       5057770        Closed      currency 1        -1878
# 1716427      246829       5057778        Closed      currency 1         -463
#
# ...

# %%
df_bureau_balance
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0              5715448               0      C
# 1              5715448              -1      C
# 2              5715448              -2      C
# 3              5715448              -3      C
# 4              5715448              -4      C
# ...                ...             ...    ...
# 27299920       5041336             -47      X
# 27299921       5041336             -48      X
# 27299922       5041336             -49      X
# 27299923       5041336             -50      X
# 27299924       5041336             -51      X
#
# [27299925 rows x 3 columns]

# %%
df_credit_card_balance
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 0           2562384      378907              -6       56.970
# 1           2582071      363914              -1    63975.555
# 2           1740877      371185              -7    31815.225
# 3           1389973      337855              -4   236572.110
# 4           1891521      126868              -1   453919.455
# ...             ...         ...             ...          ...
# 3840307     1036507      328243              -9        0.000
# 3840308     1714892      347207              -9        0.000
# 3840309     1302323      215757              -9   275784.975
# 3840310     1624872      430337             -10        0.000
# 3840311     2411345      236760             -10        0.000
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 0                         135000                       0.0
# 1                          45000                    2250.0
# ...

# %%
df_installments_payments
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
df_pov_cash_balance
# Out:
#           SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0            1803195      182943             -31            48.0
# 1            1715348      367990             -33            36.0
# 2            1784872      397406             -32            12.0
# 3            1903291      269225             -35            48.0
# 4            2341044      334279             -35            36.0
# ...              ...         ...             ...             ...
# 10001353     2448283      226558             -20             6.0
# 10001354     1717234      141565             -19            12.0
# 10001355     1283126      315695             -21            10.0
# 10001356     1082516      450255             -22            12.0
# 10001357     1259607      174278             -52            16.0
#
#           CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                          45.0               Active       0           0
# ...

# %%
df_previous_application
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0           2030495      271877     Consumer loans     1730.430
# 1           2802425      108129         Cash loans    25188.615
# 2           2523466      122040         Cash loans    15060.735
# 3           2819243      176158         Cash loans    47041.335
# 4           1784265      202054         Cash loans    31924.395
# ...             ...         ...                ...          ...
# 1670209     2300464      352015     Consumer loans    14704.290
# 1670210     2357031      334635     Consumer loans     6622.020
# 1670211     2659632      249544     Consumer loans    11520.855
# 1670212     2785582      400317         Cash loans    18821.520
# 1670213     2418762      261212         Cash loans    16431.300
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0                17145.0     17145.0               0.0          17145.0
# ...

# %%
df_sample_submission
# Out:
#        SK_ID_CURR  TARGET
# 0          100001     0.5
# 1          100005     0.5
# 2          100013     0.5
# 3          100028     0.5
# 4          100038     0.5
# ...           ...     ...
# 48739      456221     0.5
# 48740      456222     0.5
# 48741      456223     0.5
# 48742      456224     0.5
# 48743      456250     0.5
#
# [48744 rows x 2 columns]
